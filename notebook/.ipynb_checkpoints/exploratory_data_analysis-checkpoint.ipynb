# %% [markdown]
# ### 1.Exploratory data analysis - Exploring Data structure and visualization of important variables
#
# Getting data from kaggle, which contains a train data and a test data in the format of .csv, along with a data desription about the attributes used for prediction. All the data and description can be found in the 'data file'.
# For more details about the project, please check(https://www.kaggle.com/c/house-prices-advanced-regression-techniques)

# %% [markdown]
# #### Getting the data and overview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("datasets/project/train.csv")
test = pd.read_csv("datasets/project/test.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
print ('The train data has {0} rows and {1} columns'.format(train.shape[0],train.shape[1]))
print ('The test data has {0} rows and {1} columns'.format(test.shape[0],test.shape[1]))
# Out:
# The train data has 1460 rows and 81 columns
# The test data has 1459 rows and 80 columns

# %% [markdown]
# #### Checking missing data in both train and test data

# %%
train_missing = (train.isnull().sum() / len(train)) * 100
train_missing = train_missing.drop(train_missing[train_missing == 0].index).sort_values(ascending=False)
train_missing
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# BsmtQual         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.xticks(rotation="90")
sns.barplot(x=train_missing.index, y=train_missing)

# %%
test_missing = (test.isnull().sum() / len(test)) * 100
test_missing = test_missing.drop(test_missing[test_missing == 0].index).sort_values(ascending=False)
test_missing
# Out:
# PoolQC          99.794380
# MiscFeature     96.504455
# Alley           92.666210
# Fence           80.123372
# FireplaceQu     50.034270
# LotFrontage     15.558602
# GarageYrBlt      5.346127
# GarageCond       5.346127
# GarageQual       5.346127
# GarageFinish     5.346127
# GarageType       5.209047
# BsmtCond         3.084304
# BsmtExposure     3.015764
# BsmtQual         3.015764
# BsmtFinType1     2.878684
# BsmtFinType2     2.878684
# MasVnrType       1.096642
# MasVnrArea       1.028101
# MSZoning         0.274160
# BsmtFullBath     0.137080
# BsmtHalfBath     0.137080
# Utilities        0.137080
# Functional       0.137080
# Exterior2nd      0.068540
# Exterior1st      0.068540
# SaleType         0.068540
# BsmtFinSF1       0.068540
# BsmtFinSF2       0.068540
# BsmtUnfSF        0.068540
# KitchenQual      0.068540
# GarageCars       0.068540
# GarageArea       0.068540
# TotalBsmtSF      0.068540
# dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.xticks(rotation="90")
sns.barplot(x=test_missing.index, y=test_missing)

# %%
print('The train data has {0} varibles with missing data'.format(train_missing.count()))
print('The test data has {0} varibles with missing data'.format(test_missing.count()))
# Out:
# The train data has 19 varibles with missing data
# The test data has 33 varibles with missing data

# %%
numeric_data = train.select_dtypes(include=[np.number])
cat_data = train.select_dtypes(exclude=[np.number])
print ("There are {} numeric and {} categorical columns in train data".format(numeric_data.shape[1],cat_data.shape[1]))
# Out:
# There are 38 numeric and 43 categorical columns in train data

# %% [markdown]
# From above, we can see there are 1460 instances of training data and 1460 of test data. Total number of attributes equals 81(including ‘Id’ and ‘SalePrice’), of which 36 is numeric, 43 categorical. 19 attributes of training data and 33 attributes of test data have missing data.

# %% [markdown]
# #### EDA of target variable 'SalesPrice'

# %%
import scipy.stats as st
y = train['SalePrice']
plt.figure()
plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)
print('Skewness is: {}'.format(y.skew()))
print('Kurtosis is: {}'.format(y.kurt()))
# Out:
# Skewness is: 1.8828757597682129
# Kurtosis is: 6.536281860064529

# %% [markdown]
# It is apparent that 'SalePrice' doesn't follow normal distribution, so before performing regression it has to be transformed. While log transformation does pretty good job, best fit is unbounded Johnson distribution.

# %%
plt.figure()
plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)
print('Skewness is: {}'.format(np.log(y).skew()))
print('Kurtosis is: {}'.format(np.log(y).kurt()))
# Out:
# Skewness is: 0.12133506220520406
# Kurtosis is: 0.8095319958036296

# %% [markdown]
# #### EDA of numeric variables

# %%
del numeric_data['Id']

# %%
num = [i for i in numeric_data.columns]
num.remove('SalePrice')
nd = pd.melt(numeric_data, value_vars = num)
g = sns.FacetGrid (nd, col='variable', col_wrap=4, sharex=False, sharey = False)
g = g.map(sns.distplot, 'value')

# %% [markdown]
# Also none of quantitative variables has normal distribution so these should be transformed as well. Some independent variables look like good candidates for log transformation, such as TotalBsmtSF, KitchenAbvGr, LotFrontage, LotArea and others. While regression transformation will smooth out some irregularities variables, they are good candidates for feature construction.

# %%
corrmat = numeric_data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=0.8, square=True);

# %% [markdown]
# We use the heat map to check the correlation between numeric variables and 'SalesPrice'. Then we check the correlation score for each variables. We can see OverallQual is main criterion in establishing house price. There are many strong correlations between variables. Garages seem to be built same year as houses, basements have generally same area as first floor which is pretty obvious. Garage area is strongly correlated with number of cars.

# %%
print (corr['SalePrice'].sort_values(ascending=False))
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %% [markdown]
# Next, we check the top 10 variables distribution and correlation individually. Some variables distribute like a linear regeression, while others are not continuous changeing, just like a categorical variables.

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd']
sns.pairplot(numeric_data[cols])
plt.show();

# %% [markdown]
# For more details, we check the OverallQual and CrliveArea variable and their correlation. As the boxplot shown, OverallQual has 10 different values and it's highly positive correlative with 'SalesPrice'. GrlivArea also shows higher positive correlation with 'SalesPrice', but with several outliers. Considering these two variables together, we can easily find the bigger GrliveArea, the higher OverallQual and leading to a higher SalesPrice. It's make sence.

# %%
# TOP1 OverallQual
numeric_data['OverallQual'].unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
sns.boxplot(x='OverallQual', y='SalePrice', data=numeric_data)
plt.title('Box Plot of OverallQual & SalePrice')
# Out:
# Text(0.5, 1.0, 'Box Plot of OverallQual & SalePrice')

# %%
# TOP2 GrlivArea
sns.scatterplot(x='GrLivArea', y='SalePrice', data=numeric_data)
plt.title('Scatter Plot of OverallQual & SalePrice')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of OverallQual & SalePrice')

# %%
# TOP 1&2
plt.figure(figsize = (12,9))
plt.plot()
for val in range(10):
    indeX = numeric_data.OverallQual == val
    plt.scatter(numeric_data.GrLivArea.loc[indeX], numeric_data.SalePrice.loc[indeX], label = val)
plt.legend(bbox_to_anchor = [1.1, 1])
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.title('Scatter Plot of GrLivArea & SalePrice & OverallQual')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of GrLivArea & SalePrice & OverallQual')

# %% [markdown]
# Next, we check the GarageCars and GarageArea variable together. Similar result is found.

# %%
# TOP3 GarageCars
sns.boxplot(x='GarageCars', y='SalePrice', data=numeric_data)
plt.title('Box Plot of GarageCars & SalePrice')
# Out:
# Text(0.5, 1.0, 'Box Plot of GarageCars & SalePrice')

# %%
# TOP4 GarageArea
sns.scatterplot(x='GarageArea', y='SalePrice', data=numeric_data)
plt.title('scatter Plot of OverallQual & SalePrice')
# Out:
# Text(0.5, 1.0, 'scatter Plot of OverallQual & SalePrice')

# %%
# TOP3&4
plt.figure(figsize = (12,9))
plt.plot()
for val in range(5):
    indeX = numeric_data.GarageCars == val
    plt.scatter(numeric_data.GarageArea.loc[indeX], numeric_data.SalePrice.loc[indeX], label = val)
plt.legend(bbox_to_anchor = [1.1, 1])
plt.xlabel('GarageArea')
plt.ylabel('SalePrice')
plt.title('Scatter Plot of GarageArea & SalePrice & CarageCars')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of GarageArea & SalePrice & CarageCars')

# %% [markdown]
# #### EDA of categorical variables

# %%
# Categorical Variables overview
cat_data.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460         1460       1460      ...            1379
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1379       1379       1379       1460      7    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Gd  MnPrv
# ...

# %% [markdown]
# With categorical variables we check distribution of SalePrice with respect to variable values and enumerate them.

# %%
# distribution of SalePrice with respect to variable values
def boxplot(x,y,**kwargs):
            sns.boxplot(x=x,y=y)
            x = plt.xticks(rotation=90)
cat = [i for i in cat_data.columns]
p = pd.melt(train, id_vars='SalePrice', value_vars=cat)
g = sns.FacetGrid (p, col='variable', col_wrap=4, sharex=False, sharey=False)
g = g.map(boxplot, 'value','SalePrice')

# %% [markdown]
# Some categories seem to more diverse with respect to SalePrice than others. Neighborhood has big impact on house prices. Most expensive seems to be Partial SaleCondition. Having pool on property seems to improve price substantially. There are also differences in variabilities between category values.
# Now, we have a visualized picture of the data and variables. It is really useful before data preprocessing.
